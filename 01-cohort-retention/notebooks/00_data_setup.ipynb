# %%
import sys

# %%
print(sys.executable)
# Out:
# /opt/anaconda3/envs/pa/bin/python

# %%
import pandas as pd, duckdb

sheets = pd.read_excel('../data/online_retail_II.xlsx', sheet_name=None)
df = pd.concat(sheets.values(), ignore_index=True)
df.to_csv('../data/online_retail.csv', index=False)
print(df.shape)

duckdb.query("SELECT * FROM '../data/online_retail.csv' LIMIT 5").df()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 3
#       1 import pandas as pd, duckdb
#       2
# ----> 3 sheets = pd.read_excel('../data/online_retail_II.xlsx', sheet_name=None)
#       4 df = pd.concat(sheets.values(), ignore_index=True)
#       5 df.to_csv('../data/online_retail.csv', index=False)
#       6 print(df.shape)
#
# File /opt/anaconda3/envs/pa/lib/python3.12/site-packages/pandas/io/excel/_base.py:481, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     479 if not isinstance(io, ExcelFile):
#     480     should_close = True
# --> 481     io = ExcelFile(
#     482         io,
# ...

# %%
# !ls ../data
# Out:
# online_retail_II.csv

# %%
import pandas as pd, duckdb

df = pd.read_csv('../data/online_retail_II.csv')
print(df.shape)

duckdb.query("SELECT * FROM '../data/online_retail_II.csv' LIMIT 5").df()
# Out:
# (1067371, 8)
#   Invoice StockCode                          Description  Quantity  \
# 0  489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1  489434    79323P                   PINK CHERRY LIGHTS        12
# 2  489434    79323W                  WHITE CHERRY LIGHTS        12
# 3  489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4  489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
#
#           InvoiceDate  Price  Customer ID         Country
# 0 2009-12-01 07:45:00   6.95      13085.0  United Kingdom
# 1 2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 2 2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 3 2009-12-01 07:45:00   2.10      13085.0  United Kingdom
# 4 2009-12-01 07:45:00   1.25      13085.0  United Kingdom

# %%
import os

# %%
os.getcwd()
# Out:
# '/Users/bhavitha/Documents/01-cohort-retention/notebooks'
